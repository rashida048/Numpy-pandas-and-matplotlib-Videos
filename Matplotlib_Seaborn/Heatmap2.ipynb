# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("nhanes_2015_2016.csv")
df.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3       1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4       1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# 1     40.0     33.2     107.9     NaN
# 2     37.0     31.0     116.5     2.0
# 3     37.7     38.3     110.1     2.0
# 4     36.0     27.2      80.4     2.0
#
# [5 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['SEQN', 'ALQ101', 'ALQ110', 'ALQ130', 'SMQ020', 'RIAGENDR', 'RIDAGEYR',
#        'RIDRETH1', 'DMDCITZN', 'DMDEDUC2', 'DMDMARTL', 'DMDHHSIZ', 'WTINT2YR',
#        'SDMVPSU', 'SDMVSTRA', 'INDFMPIR', 'BPXSY1', 'BPXDI1', 'BPXSY2',
#        'BPXDI2', 'BMXWT', 'BMXHT', 'BMXBMI', 'BMXLEG', 'BMXARML', 'BMXARMC',
#        'BMXWAIST', 'HIQ210'],
#       dtype='object')

# %%
df = df[['BPXSY1', 'BPXDI1', 'BPXSY2', 'BPXDI2', 'BMXWT', 'BMXHT', 'BMXBMI']]
df.head()
# Out:
#    BPXSY1  BPXDI1  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI
# 0   128.0    70.0   124.0    64.0   94.8  184.5    27.8
# 1   146.0    88.0   140.0    88.0   90.4  171.4    30.8
# 2   138.0    46.0   132.0    44.0   83.4  170.1    28.8
# 3   132.0    72.0   134.0    68.0  109.8  160.9    42.4
# 4   100.0    70.0   114.0    54.0   55.2  164.9    20.3

# %%
cor = df.corr()
cor
# Out:
#           BPXSY1    BPXDI1    BPXSY2    BPXDI2     BMXWT     BMXHT    BMXBMI
# BPXSY1  1.000000  0.316531  0.962287  0.277681  0.122512 -0.007911  0.135201
# BPXDI1  0.316531  1.000000  0.329843  0.884722  0.147788  0.119566  0.098179
# BPXSY2  0.962287  0.329843  1.000000  0.303847  0.143145 -0.002782  0.155575
# BPXDI2  0.277681  0.884722  0.303847  1.000000  0.141474  0.115055  0.094868
# BMXWT   0.122512  0.147788  0.143145  0.141474  1.000000  0.431386  0.884133
# BMXHT  -0.007911  0.119566 -0.002782  0.115055  0.431386  1.000000 -0.025978
# BMXBMI  0.135201  0.098179  0.155575  0.094868  0.884133 -0.025978  1.000000

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(data = cor, annot = True, cmap = 'mako', center = 0)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(data = cor, annot = True, cmap = 'mako', center = 0, vmin = 0.1, vmax = 0.95, cbar = False)
# Out:
# <AxesSubplot:>
